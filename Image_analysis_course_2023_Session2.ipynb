# %% [markdown]
# <a href="https://colab.research.google.com/github/microscopy-Core-ISMMS/ImageAnalysisCourse/blob/main/Image_analysis_course_2023_Session2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 5 - Do's and Dont's

# %% [markdown]
# **Image Processing & Analysis: Dos and Don’ts**
#
# • Manipulation should be done on a copy not the original data
#
# • Simple adjustments to the entire image are usually acceptable
#
# • Check journal’s guidances
#
# • Ethical guidelines: http://www.ncbi.nlm.nih.gov/pubmed/20567932
#
# • Be honest, always describe the adjustments made
#
# • Do not hide information (brightness, contrast, gamma)
#
# • Do not create/destroy information (interpolation, bit depth conversion)
#
# http://jcb.rupress.org/cgi/content/full/166/1/11 - JCB article about image manipulation.
#
# http://microscopy.arizona.edu/learn/digital image ethics - Nice article, picking the best image is not the same as picking the image that fits your
# hypothesis!
#
# Journals actively check submitted images for tell tale signs of manipulation.
# Duplications, deletions, smudge tool, image noise, background.

# %% [markdown]
# # Module 6 - Mathematical operations on images

# %% [markdown]
# Mathematical operations (addition, subtraction, multiplication, division,
# log, ...) applied to each pixel of the image:
#
# **P1 = f (P0), where f (P0(x, y )) = P0(x, y ) + a**
#
# **P3 = g (P1, P2), where g (P1, P2) = P1(x, y) + P2(x, y)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 7** (10 mins)
#
# - Open image 'Blobs.tif'.
# - Add a number 100 to the image (Process-> Math -> Add).
# - Observe the bit-depth of the image and the pixel values of the resultant image.
#
# - Can you subtract the same number from the image and obatin the original image?

# %% [markdown]
# **Exercise 8** (10 mins)
# - Open image 'Blobs.tif'.
# - Make a new blank image (File -> New -> Image); Name the image, set the other paramters like bit depth, width, height and slices same as Blobs.
#
#
# ![image.png](data:image/png;base64,...)
#
# - Add some noise to the blank image (Process-> Noise -> Salt and Pepper).
# - Add the two images - Blobs + Noise (Process -> Image Calculator)
#
# ![image.png](data:image/png;base64,...)
#
# - Subtract the noise from the noisy image. Do you get back the same original image that we started with?

# %% [markdown]
# **Understanding Noise**
#
#
# - Salt and Pepper noise is caused by data loss or saturation, this type of noise contains random white (salt) and black (pepper) pixels in the image. The white pixels or spots are caused by erroneous saturation and the black pixels or spots are caused by a failed response from the sensor.
#
# ![image.png](data:image/png;base64,...)
#
# - Uniform noise can occur with low lighting, for example. This type of noise has the effect of adding or subtracting a random amount to each value when the images are captured. The range of possible values added or taken away (a) reflect the severity of the noise, and forms a probability density function (PDF) where the range is (-a to a).
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# - Gaussian noise is a common type of noise to find affecting all image data to some degree. Sensors often give a reading slightly away from the true value. For an individual image what we have is a signal corrupted by a random value (as with uniform noise), but this time the chance of more extreme random values is less than with small errors. The distribution of errors can be represented as:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Module 7 - Filters

# %% [markdown]
# - Noise reduction is the process of removing as much of the noise from an image as possible - we can never remove it all perfectly.
#
# - There are different types of noise, and so there are correspondingly different noise reduction processes that are used depending on the noise type.
#
# - Noise reduction processes usually take the form of filters.
#
# - These work by examining a small window of pixels called a kernel, for example 3 x 3 pixels in size, then recalculating the middle pixel based on the neighboring pixels in this window.
# - This window is then moved across the image typically a pixel at a time, and applied again until the whole image has been recalculated.
# - We can perform different calculations on the pixels in the kernel to handle different kinds of noise, but in all cases we are using local image statistics (such as a mean) to recalculate the center value based on the context of its neighbours.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Common ImageJ filters**
#
# **Smooth** (Process->Smooth)
#
# Blurs the active image or selection. This filter replaces each pixel with the average of its 3x3 neighborhood.
#
# **Sharpen**
#
# Increases contrast and accentuates detail in the image or selection, but may also accentuate noise. This filter uses the following weighting factors to replace each pixel with a weighted average of the 3x3 neighborhood.
#
#                     -1 -1 -1
#                     -1 12 -1
#                     -1 -1 -1
#
# **Find Edges**
#
# Uses a Sobel edge detector to highlight sharp changes in intensity in the active image or selection. Two 3x3 convolution kernels (show below) are used to generate vertical and horizontal derivatives. The final image is produced by combining the two derivatives using the square root of the sum of the squares.
#
#           1  2  1     1  0 -1
#           0  0  0     2  0 -2
#          -1 -2 -1     1  0 -1
#
#          Vertical     Horizontal
#
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Gaussian (fast smoothing)
#
# - Median (slow, keeps edges)
#
# - Mean (fast smotthing)
#
# - Min / Max (~ dims / brightens)
#
# - Unsharp mask (~ enhances edges & noise)
#
# - Variance (~ shows image gradients)
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 9: Filters** (15 mins)
#
# - Open the image 'boats.tif'.
# - Duplicate the image and rename it 'S_P', add Salt and Pepper Noise
# - Try applying different filters on the image to reduce the effect, which one works the best of the noise?
# - How does the despeckle option work on such noise (Process -> Noise -> Despeckle).
#
#
# - Duplicate the original image again and rename it 'G_N' and add Gaussian noise (Process -> Noise -> Add Specified Noise ...)
# - Try applying different filters on the image to reduce the effect, which one works the best of the noise?

# %% [markdown]
# # Module 8 - Background Corrections

# %% [markdown]
# **Background corrections**
# - Even background across the image - Image /adjust > Brightness-Contrast
# Uneven background
# - Process / Substract Background (rolling ball algorithm) -
# Flat field correction (brightfield)
# - Process / Calculator Plus (requires an image of just background)
# - Many other ways …
# http://imagejdocu.tudor.lu/doku.php?id=howto:working:how_to_correct_background_illumination_in_brightfield_microscopy.

# %% [markdown]
# Even background across the image
#
# Check Image -> adjust -> Brightness-Contrast
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Uneven background**
#
# Process / Substract Background (rolling ball algorithm)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 10 -Rolling ball background correction** (10 minutes)
#
# - Open image 'Cell Colony.tif'.
#
# - Draw a line diagonally from top left to bottom right across image
# (Try to go through a few blobs)
#
# - Open the Histogram (H) & Plot Profile (K) (use both in Live mode)
# - Fix the Y axis range to 0-255
# (More>> Set Range…)
# - On the Cell Colony image: Process / Subtract background… (use Preview)
# - Adjust the radius: 50, 10, 2 pixels, & smoothing (Toggle Preview)
#
# What happens when you disable smoothing? Does this matter?

# %% [markdown]
# **Exercise 11-  Image Calculator plus (removes a known background from other images)** (5 mins)
#
# - Open the images in the background folder (Exercise images).
# - Measure the mean intensity of the background (flat-field) image (how??)
# - Process / Calculator Plus:
# - i1 = Image i2 = background
#
# - Use divide, and add the mean intensity of the background image as k1 (value = 203).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 12: Cell Counting** (5 mins)
#
#
# - Open the image 'Blobs.tif'
# - For counting the number of blobs, open Process -> Find Maxima...
#
# ![image.png](data:image/png;base64,...)
#
# - Turn on the Preview point selection option to view the results.
#
# - Try different Prominance values (2,20,50,100). Prominance values determines how much the pixel stands-out with respect to its surroundings.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
